# %%
# Necessary imports
import random
import math

# %%
# Read input from the benchmark file
def read_input(file_path):
    with open(file_path, 'r') as file:
        num_objects = int(file.readline().strip())
        total_capacity = int(file.readline().strip())
        weights = [int(line.strip()) for line in file]

    return num_objects, total_capacity, weights

# Import the benchmark:
file_path = '/content/benchmark100.txt'
num_objects, total_capacity, weights = read_input(file_path)

# %%
# Necessary imports
import random
import math

class BinPacker:
  def __init__(self, items, bin_capacity):
    self.items = items
    self.bin_capacity = bin_capacity
    self.bins = []
    self.heuristics = [self.first_fit_decreasing, self.next_fit_decreasing, self.best_fit_decreasing]  # Low-level heuristics
    self.avg_performance = {h: 1 for h in self.heuristics}  # Track average performance
    self.exploration_param = 0.1  # Exploration probability
    self.iteration_count = 0  # Iteration counter for UCB

  """ LOW LEVEL HEURISTICS IMPLIED FOR BPP """
  """ ____________________________________ """
  def first_fit_decreasing(self, current_bin, item, bin_capacity):
    """
    First-Fit Decreasing (FFD) heuristic.
    """
    if sum(current_bin) + item <= bin_capacity:
      current_bin.append(item)
      return True
    return False

  def next_fit_decreasing(self, current_bin, item, bin_capacity):
    """
    Next-Fit Decreasing (NFD) heuristic.
    """
    if sum(current_bin) + item <= bin_capacity:
      current_bin.append(item)
      return True
    else:
      self.bins.append(current_bin)
      current_bin = [item]
    return True

  def best_fit_decreasing(self, current_bin, item, bin_capacity):
    """
    Best-Fit Decreasing (BFD) heuristic.
    """
    if sum(current_bin) + item <= bin_capacity:
      current_bin.append(item)
      return True

    best_bin = None
    best_remaining_space = -float('inf')
    for bin in self.bins:
      remaining_space = bin_capacity - sum(bin)
      if remaining_space >= item and remaining_space > best_remaining_space:
        best_bin = bin
        best_remaining_space = remaining_space

    if best_bin is not None:
      best_bin.append(item)
      return True
    else:
      self.bins.append(current_bin)
      current_bin = [item]
    return True
  """ ____________________________________ """

  def calculate_ucb(self, heuristic):
    """
    Calculate UCB (Upper Confidence Bound) for a heuristic.
    """
    if self.avg_performance[heuristic] == 0:
      # Avoid division by zero for new heuristics
      return float('inf')
    return self.avg_performance[heuristic] + random.random() * self.exploration_param * \
           math.sqrt(math.log(self.iteration_count) / self.avg_performance[heuristic])

  def select_heuristic(self):
    """
    Select a heuristic using UCB.
    """
    self.iteration_count += 1

    best_ucb = -float('inf')
    best_heuristic = None
    for heuristic in self.heuristics:
      ucb_value = self.calculate_ucb(heuristic)
      print(f"Heuristic : {heuristic.__name__} , performance: {ucb_value}")
      if ucb_value > best_ucb:
        best_ucb = ucb_value
        best_heuristic = heuristic
    return best_heuristic

  def pack_items(self):
    """
    Pack items into bins using the selected heuristic.
    """
    current_bin = []
    for item in self.items:
      selected_heuristic = self.select_heuristic()
      print(f"selected heuristic : {selected_heuristic.__name__}\n")
      if selected_heuristic(current_bin, item, self.bin_capacity):
        continue  # Item fits in current bin
      self.bins.append(current_bin)
      current_bin = [item]  # Start a new bin
    self.bins.append(current_bin)  # Add the last bin
    return self.bins

  def update_performance(self):
    """
    Update the average performance for each heuristic after packing.
    """
    num_bins = len(self.bins)
    for heuristic in self.heuristics:
      self.avg_performance[heuristic] = (self.avg_performance[heuristic] * (self.iteration_count - 1) + num_bins) / self.iteration_count

# %%
# Example usage - one round
items = [10, 5, 3,1,4]
bin_capacity = 10

#items = weights
#bin_capacity = total_capacity

packer = BinPacker(items, bin_capacity)
packed_bins = packer.pack_items()

print("Packed items into", len(packed_bins), "bins")
for bin in packed_bins:
  print(bin)

packer.update_performance()  # Update performance after packing
# Out:
# Heuristic : first_fit_decreasing , performance: 1.0
# Heuristic : next_fit_decreasing , performance: 1.0
# Heuristic : best_fit_decreasing , performance: 1.0
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0423441146686434
# Heuristic : next_fit_decreasing , performance: 1.0023798649174378
# Heuristic : best_fit_decreasing , performance: 1.027738602461606
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0475239950458246
# Heuristic : next_fit_decreasing , performance: 1.0089018397019305
# Heuristic : best_fit_decreasing , performance: 1.0927795088300056
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1066117333999919
# Heuristic : next_fit_decreasing , performance: 1.0330860090105152
# Heuristic : best_fit_decreasing , performance: 1.0420070777227703
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0995287856087443
# Heuristic : next_fit_decreasing , performance: 1.093417490602513
# Heuristic : best_fit_decreasing , performance: 1.07264453302932
# selected heuristic : first_fit_decreasing
#
# Packed items into 3 bins
# [10]
# [5, 3, 1]
# [4]

# %%
# Example usage - multiple rounds
#items = [10, 5, 8, 7, 3, 2, 9]
#bin_capacity = 15

items = weights
bin_capacity = total_capacity

num_rounds = 10  # Number of rounds to test
res_rounds = []

for _ in range(num_rounds):
  #random.shuffle(items)  # Shuffle items for randomness in each round
  packer = BinPacker(items.copy(), bin_capacity)

  packed_bins = packer.pack_items()
  num_bins_used = len(packed_bins)

  chosen_heuristic = packer.select_heuristic()  # Access the chosen heuristic for this round
  print(f"\nRound {_ + 1}: Selected Heuristic - {chosen_heuristic.__name__}, Number of Bins Used - {num_bins_used}")
  res_rounds.append([_+1, chosen_heuristic.__name__,num_bins_used ])
  for bin in packed_bins:
    print(bin)

  packer.update_performance()  # Update performance after packing
  print("\n SUMMARY \n", res_rounds)
# Out:
# Heuristic : first_fit_decreasing , performance: 1.0
# Heuristic : next_fit_decreasing , performance: 1.0
# Heuristic : best_fit_decreasing , performance: 1.0
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0175247481882994
# Heuristic : next_fit_decreasing , performance: 1.0669529002443157
# Heuristic : best_fit_decreasing , performance: 1.0280485527648913
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0305124613302288
# Heuristic : next_fit_decreasing , performance: 1.0844657360866972
# Heuristic : best_fit_decreasing , performance: 1.0182173143552296
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0574418674699426
# Heuristic : next_fit_decreasing , performance: 1.0882982235844954
# Heuristic : best_fit_decreasing , performance: 1.0816694807539824
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.069033457077569
# Heuristic : next_fit_decreasing , performance: 1.022722294805893
# Heuristic : best_fit_decreasing , performance: 1.087594013516411
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.000914201020898
# Heuristic : next_fit_decreasing , performance: 1.0177977991758185
# Heuristic : best_fit_decreasing , performance: 1.125503877579167
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0627205296624151
# Heuristic : next_fit_decreasing , performance: 1.0644954080465594
# Heuristic : best_fit_decreasing , performance: 1.0846924978102412
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0867646421113006
# Heuristic : next_fit_decreasing , performance: 1.1306194882114877
# Heuristic : best_fit_decreasing , performance: 1.112471601151163
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0175170453360154
# Heuristic : next_fit_decreasing , performance: 1.0186367710638888
# Heuristic : best_fit_decreasing , performance: 1.1436060099840948
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.013697921053843
# Heuristic : next_fit_decreasing , performance: 1.0325588103042755
# Heuristic : best_fit_decreasing , performance: 1.128753064371824
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.146129380768413
# Heuristic : next_fit_decreasing , performance: 1.0496444777142113
# Heuristic : best_fit_decreasing , performance: 1.1345027962565604
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0462656150396876
# Heuristic : next_fit_decreasing , performance: 1.0157014056603606
# Heuristic : best_fit_decreasing , performance: 1.1089541363897941
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1402582297850103
# Heuristic : next_fit_decreasing , performance: 1.1414745403356983
# Heuristic : best_fit_decreasing , performance: 1.1076406641679337
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0420716135210797
# Heuristic : next_fit_decreasing , performance: 1.0513380250481135
# Heuristic : best_fit_decreasing , performance: 1.0975335073554675
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.068473785233373
# Heuristic : next_fit_decreasing , performance: 1.0867774322268384
# Heuristic : best_fit_decreasing , performance: 1.0096769697558494
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0828484550175954
# Heuristic : next_fit_decreasing , performance: 1.1195937735479395
# Heuristic : best_fit_decreasing , performance: 1.1313783217821554
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0136744704201401
# Heuristic : next_fit_decreasing , performance: 1.0923996133054266
# Heuristic : best_fit_decreasing , performance: 1.0595216648351717
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1368811809099912
# Heuristic : next_fit_decreasing , performance: 1.1540142928274297
# Heuristic : best_fit_decreasing , performance: 1.1446579878014136
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.086105522640405
# Heuristic : next_fit_decreasing , performance: 1.1294185237987853
# Heuristic : best_fit_decreasing , performance: 1.146677378105395
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0753525608964878
# Heuristic : next_fit_decreasing , performance: 1.083003813557853
# Heuristic : best_fit_decreasing , performance: 1.1245221336121352
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.02405378456183
# Heuristic : next_fit_decreasing , performance: 1.1230814933141606
# Heuristic : best_fit_decreasing , performance: 1.0823069853494252
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0005981850481809
# Heuristic : next_fit_decreasing , performance: 1.0587041705322107
# Heuristic : best_fit_decreasing , performance: 1.1001565525723236
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0332265448038116
# Heuristic : next_fit_decreasing , performance: 1.0556965813174115
# Heuristic : best_fit_decreasing , performance: 1.1188233882600978
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1226067364702186
# Heuristic : next_fit_decreasing , performance: 1.1502544669800545
# Heuristic : best_fit_decreasing , performance: 1.013920998609885
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1696709559052378
# Heuristic : next_fit_decreasing , performance: 1.0066641289263427
# Heuristic : best_fit_decreasing , performance: 1.0043998842103652
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1136909455678916
# Heuristic : next_fit_decreasing , performance: 1.080359161176331
# Heuristic : best_fit_decreasing , performance: 1.0184191758823045
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1485414342302116
# Heuristic : next_fit_decreasing , performance: 1.0966510486333498
# Heuristic : best_fit_decreasing , performance: 1.1174393903262823
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.170733825682124
# Heuristic : next_fit_decreasing , performance: 1.0505661412548588
# Heuristic : best_fit_decreasing , performance: 1.0708667161155896
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1057285749005352
# Heuristic : next_fit_decreasing , performance: 1.122801182056349
# Heuristic : best_fit_decreasing , performance: 1.0501616933047553
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.089994669179275
# Heuristic : next_fit_decreasing , performance: 1.1392859982552472
# Heuristic : best_fit_decreasing , performance: 1.0260435299091677
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0653502057191113
# Heuristic : next_fit_decreasing , performance: 1.0234703687531357
# Heuristic : best_fit_decreasing , performance: 1.0860088457475592
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1275002128129614
# Heuristic : next_fit_decreasing , performance: 1.1732306994705082
# Heuristic : best_fit_decreasing , performance: 1.1811221342686014
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1305802564838185
# Heuristic : next_fit_decreasing , performance: 1.1283224960498595
# Heuristic : best_fit_decreasing , performance: 1.1365384290562073
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0143593439119758
# Heuristic : next_fit_decreasing , performance: 1.0628880182161533
# Heuristic : best_fit_decreasing , performance: 1.085481268215869
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1868455827841895
# Heuristic : next_fit_decreasing , performance: 1.1627289527864808
# Heuristic : best_fit_decreasing , performance: 1.0793750919967786
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1651986004190364
# Heuristic : next_fit_decreasing , performance: 1.0207967945344694
# Heuristic : best_fit_decreasing , performance: 1.1652386005324684
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1616335899962835
# Heuristic : next_fit_decreasing , performance: 1.0797313087004559
# Heuristic : best_fit_decreasing , performance: 1.009736879575298
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1830759446467012
# Heuristic : next_fit_decreasing , performance: 1.0553271914968376
# Heuristic : best_fit_decreasing , performance: 1.0372041326723629
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1749313809411668
# Heuristic : next_fit_decreasing , performance: 1.1658053495824907
# Heuristic : best_fit_decreasing , performance: 1.0422735886857368
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0049957378185654
# Heuristic : next_fit_decreasing , performance: 1.14865698144174
# Heuristic : best_fit_decreasing , performance: 1.103163310410068
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1923679925781638
# Heuristic : next_fit_decreasing , performance: 1.1693222840606936
# Heuristic : best_fit_decreasing , performance: 1.087854557036967
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0722240691086051
# Heuristic : next_fit_decreasing , performance: 1.0300630205436265
# Heuristic : best_fit_decreasing , performance: 1.1176320214142357
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.122622128450246
# Heuristic : next_fit_decreasing , performance: 1.1835538458625239
# Heuristic : best_fit_decreasing , performance: 1.0135816400966873
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1509403395891584
# Heuristic : next_fit_decreasing , performance: 1.1741010648252017
# Heuristic : best_fit_decreasing , performance: 1.0655811485825255
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0628203271445884
# Heuristic : next_fit_decreasing , performance: 1.1257698501454632
# Heuristic : best_fit_decreasing , performance: 1.1741677257013574
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1293400866901422
# Heuristic : next_fit_decreasing , performance: 1.1532726516625602
# Heuristic : best_fit_decreasing , performance: 1.1520523768974482
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1777592438574254
# Heuristic : next_fit_decreasing , performance: 1.0662177204624588
# Heuristic : best_fit_decreasing , performance: 1.121985607384146
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1394771168222229
# Heuristic : next_fit_decreasing , performance: 1.024329000314669
# Heuristic : best_fit_decreasing , performance: 1.0682555657001893
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0027868894058158
# Heuristic : next_fit_decreasing , performance: 1.1596966736702328
# Heuristic : best_fit_decreasing , performance: 1.166365131158411
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1672244854987284
# Heuristic : next_fit_decreasing , performance: 1.0759117991497873
# Heuristic : best_fit_decreasing , performance: 1.0652375245530363
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1922158025447411
# Heuristic : next_fit_decreasing , performance: 1.0601900273356526
# Heuristic : best_fit_decreasing , performance: 1.1876915432847737
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1760408477697784
# Heuristic : next_fit_decreasing , performance: 1.1034830811955485
# Heuristic : best_fit_decreasing , performance: 1.15352251412848
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.156030833991602
# Heuristic : next_fit_decreasing , performance: 1.143820759247047
# Heuristic : best_fit_decreasing , performance: 1.0208711874363505
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0851698633660662
# Heuristic : next_fit_decreasing , performance: 1.128299590238073
# Heuristic : best_fit_decreasing , performance: 1.003711411037748
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0487365831294202
# Heuristic : next_fit_decreasing , performance: 1.1266440031608356
# Heuristic : best_fit_decreasing , performance: 1.0461746776767697
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0153856197559685
# Heuristic : next_fit_decreasing , performance: 1.1936535308397855
# Heuristic : best_fit_decreasing , performance: 1.1575829307361305
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0010094476534805
# Heuristic : next_fit_decreasing , performance: 1.1078253566898706
# Heuristic : best_fit_decreasing , performance: 1.168655517985472
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0071144525924707
# Heuristic : next_fit_decreasing , performance: 1.092114302532243
# Heuristic : best_fit_decreasing , performance: 1.1003272980267675
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1679043755037648
# Heuristic : next_fit_decreasing , performance: 1.0208080833283117
# Heuristic : best_fit_decreasing , performance: 1.0316570735793122
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1973004383280865
# Heuristic : next_fit_decreasing , performance: 1.0537091400631349
# Heuristic : best_fit_decreasing , performance: 1.011020262465705
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0412730462437105
# Heuristic : next_fit_decreasing , performance: 1.193784323439594
# Heuristic : best_fit_decreasing , performance: 1.0490489928629725
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0098714202948702
# Heuristic : next_fit_decreasing , performance: 1.0353951705068416
# Heuristic : best_fit_decreasing , performance: 1.0290297821866905
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0126683217008954
# Heuristic : next_fit_decreasing , performance: 1.1748227808475895
# Heuristic : best_fit_decreasing , performance: 1.0334784564147417
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0922790055188016
# Heuristic : next_fit_decreasing , performance: 1.1739864361074128
# Heuristic : best_fit_decreasing , performance: 1.0107029554049656
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0048866062201445
# Heuristic : next_fit_decreasing , performance: 1.0304445699904468
# Heuristic : best_fit_decreasing , performance: 1.0162390818555815
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1480359134549116
# Heuristic : next_fit_decreasing , performance: 1.1180334483159764
# Heuristic : best_fit_decreasing , performance: 1.0619339832949468
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1116556385128797
# Heuristic : next_fit_decreasing , performance: 1.0748123168302126
# Heuristic : best_fit_decreasing , performance: 1.0894558355151978
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0370432788475341
# Heuristic : next_fit_decreasing , performance: 1.1235003972327424
# Heuristic : best_fit_decreasing , performance: 1.0352275579846235
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.121561337024035
# Heuristic : next_fit_decreasing , performance: 1.0959694765375967
# Heuristic : best_fit_decreasing , performance: 1.088365585257641
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0352872028293263
# Heuristic : next_fit_decreasing , performance: 1.0251813484360444
# Heuristic : best_fit_decreasing , performance: 1.100170711316763
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1187172439940396
# Heuristic : next_fit_decreasing , performance: 1.16971093930566
# Heuristic : best_fit_decreasing , performance: 1.090972633767422
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0940417753720253
# Heuristic : next_fit_decreasing , performance: 1.1075803915722586
# Heuristic : best_fit_decreasing , performance: 1.1060936364630052
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0823647478864762
# Heuristic : next_fit_decreasing , performance: 1.0111861677331575
# Heuristic : best_fit_decreasing , performance: 1.077477955929467
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.004584842504779
# Heuristic : next_fit_decreasing , performance: 1.1623921791838427
# Heuristic : best_fit_decreasing , performance: 1.0593364377785073
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0024262246697735
# Heuristic : next_fit_decreasing , performance: 1.169884251313952
# Heuristic : best_fit_decreasing , performance: 1.1909603411564247
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0772532897638558
# Heuristic : next_fit_decreasing , performance: 1.1672155628083678
# Heuristic : best_fit_decreasing , performance: 1.1554264386062145
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1861388272838853
# Heuristic : next_fit_decreasing , performance: 1.064819918158771
# Heuristic : best_fit_decreasing , performance: 1.0425232924069103
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0889698921459852
# Heuristic : next_fit_decreasing , performance: 1.0094957420999182
# Heuristic : best_fit_decreasing , performance: 1.0752846883213893
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.06390325200929
# Heuristic : next_fit_decreasing , performance: 1.2075877113602156
# Heuristic : best_fit_decreasing , performance: 1.0613604294105616
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.064839172474133
# Heuristic : next_fit_decreasing , performance: 1.0290083768564928
# Heuristic : best_fit_decreasing , performance: 1.202367188338171
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0147573195101254
# Heuristic : next_fit_decreasing , performance: 1.0197021807941156
# Heuristic : best_fit_decreasing , performance: 1.1797100206463387
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0637355996536177
# Heuristic : next_fit_decreasing , performance: 1.1196136146536777
# Heuristic : best_fit_decreasing , performance: 1.2041051716553228
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1175403004444624
# Heuristic : next_fit_decreasing , performance: 1.0530227786066242
# Heuristic : best_fit_decreasing , performance: 1.0417326207248068
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1139570179605225
# Heuristic : next_fit_decreasing , performance: 1.0808973002607252
# Heuristic : best_fit_decreasing , performance: 1.0514988739636981
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1133802763206133
# Heuristic : next_fit_decreasing , performance: 1.1123399180960656
# Heuristic : best_fit_decreasing , performance: 1.0418000749029275
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0746729105405604
# Heuristic : next_fit_decreasing , performance: 1.1121282381811035
# Heuristic : best_fit_decreasing , performance: 1.0334161179412664
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1761419194223044
# Heuristic : next_fit_decreasing , performance: 1.0099917658151076
# Heuristic : best_fit_decreasing , performance: 1.158635604991593
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1484333498567378
# Heuristic : next_fit_decreasing , performance: 1.1683603860780556
# Heuristic : best_fit_decreasing , performance: 1.0231019249576976
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.053310456142726
# Heuristic : next_fit_decreasing , performance: 1.1346584256150825
# Heuristic : best_fit_decreasing , performance: 1.033373130608209
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0241080241312006
# Heuristic : next_fit_decreasing , performance: 1.108690497146597
# Heuristic : best_fit_decreasing , performance: 1.1615785185363445
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.090427657333088
# Heuristic : next_fit_decreasing , performance: 1.089862214606435
# Heuristic : best_fit_decreasing , performance: 1.0511760861163466
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1754710295599335
# Heuristic : next_fit_decreasing , performance: 1.0702101853607235
# Heuristic : best_fit_decreasing , performance: 1.1402144300227233
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.2044629121589008
# Heuristic : next_fit_decreasing , performance: 1.0155155040696677
# Heuristic : best_fit_decreasing , performance: 1.0996516566266656
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.030590460237895
# Heuristic : next_fit_decreasing , performance: 1.0443058024374887
# Heuristic : best_fit_decreasing , performance: 1.1950656453239337
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1806748808594303
# Heuristic : next_fit_decreasing , performance: 1.018361107772799
# Heuristic : best_fit_decreasing , performance: 1.0199849431759265
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1367914311142093
# Heuristic : next_fit_decreasing , performance: 1.0094530598806906
# Heuristic : best_fit_decreasing , performance: 1.0097699513291136
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1880661190114503
# Heuristic : next_fit_decreasing , performance: 1.0728587981225868
# Heuristic : best_fit_decreasing , performance: 1.0284837924814516
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0069700489688795
# Heuristic : next_fit_decreasing , performance: 1.0765300139061704
# Heuristic : best_fit_decreasing , performance: 1.0886260247858983
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0587886824347135
# Heuristic : next_fit_decreasing , performance: 1.1476050660319115
# Heuristic : best_fit_decreasing , performance: 1.152912336201588
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.161004995243647
# Heuristic : next_fit_decreasing , performance: 1.1127425431778242
# Heuristic : best_fit_decreasing , performance: 1.1343010661716513
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1727817432993386
# Heuristic : next_fit_decreasing , performance: 1.2031050959819158
# Heuristic : best_fit_decreasing , performance: 1.0066995445529086
#
# Round 1: Selected Heuristic - next_fit_decreasing, Number of Bins Used - 71
# [70]
# [70]
# [70]
# [70]
# [70]
# [70]
# [70]
# [70]
# [70]
# [70]
# [64]
# [64]
# [64]
# [64]
# [64]
# [64]
# [64]
# [64]
# [64]
# [64]
# [64]
# [64]
# [64]
# [64]
# [58, 28]
# [58, 25]
# [58, 20]
# [57, 29]
# [57, 29]
# [57, 29]
# [57, 29]
# [57, 29]
# [57, 29]
# [57, 29]
# [53, 29]
# [53, 29]
# [52, 47]
# [52, 43]
# [52, 43]
# [52, 43]
# [51, 49]
# [51, 49]
# [51, 49]
# [51, 49]
# [51, 49]
# [47, 47]
# [47, 46]
# [46, 46]
# [46, 46]
# [46, 46]
# [46, 46]
# [41, 41]
# [41, 41]
# [41, 41]
# [41, 41]
# [41, 41]
# [41, 41]
# [37, 36]
# [37, 36]
# [36, 36]
# [36, 36]
# [36, 36]
# [34, 33, 31]
# [34, 33, 31]
# [30, 30, 29]
# [28, 27, 26]
# [28, 27, 26]
# [26, 26, 25]
# [24, 24, 23, 23]
# [23, 22, 20, 20]
# [20]
#
#  SUMMARY
#  [[1, 'next_fit_decreasing', 71]]
# Heuristic : first_fit_decreasing , performance: 1.0
# Heuristic : next_fit_decreasing , performance: 1.0
# Heuristic : best_fit_decreasing , performance: 1.0
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0740642868458974
# Heuristic : next_fit_decreasing , performance: 1.0562341874682204
# Heuristic : best_fit_decreasing , performance: 1.0800943465081103
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0255164060768758
# Heuristic : next_fit_decreasing , performance: 1.0574510749014898
# Heuristic : best_fit_decreasing , performance: 1.104787711302568
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1143770766431313
# Heuristic : next_fit_decreasing , performance: 1.0086047237797715
# Heuristic : best_fit_decreasing , performance: 1.0799091097361533
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0689169696740548
# Heuristic : next_fit_decreasing , performance: 1.1188205664904998
# Heuristic : best_fit_decreasing , performance: 1.0035009741893712
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.038171176436305
# Heuristic : next_fit_decreasing , performance: 1.0277817569631114
# Heuristic : best_fit_decreasing , performance: 1.0782548672665777
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0780279263423986
# Heuristic : next_fit_decreasing , performance: 1.1047992711340284
# Heuristic : best_fit_decreasing , performance: 1.1261573504157638
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0398585549173758
# Heuristic : next_fit_decreasing , performance: 1.1052381256381463
# Heuristic : best_fit_decreasing , performance: 1.09645911869697
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0671235385128846
# Heuristic : next_fit_decreasing , performance: 1.117835396590548
# Heuristic : best_fit_decreasing , performance: 1.118800502270176
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.032286039289049
# Heuristic : next_fit_decreasing , performance: 1.105214148389999
# Heuristic : best_fit_decreasing , performance: 1.0100494403903444
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0500422455646259
# Heuristic : next_fit_decreasing , performance: 1.142586261897176
# Heuristic : best_fit_decreasing , performance: 1.1344427049281682
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0654459943909245
# Heuristic : next_fit_decreasing , performance: 1.0427552166584089
# Heuristic : best_fit_decreasing , performance: 1.087962713031001
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0349223644402525
# Heuristic : next_fit_decreasing , performance: 1.1007463695174287
# Heuristic : best_fit_decreasing , performance: 1.039206476275073
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0439866668898548
# Heuristic : next_fit_decreasing , performance: 1.0922475058801746
# Heuristic : best_fit_decreasing , performance: 1.0360134032045238
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1171691906748327
# Heuristic : next_fit_decreasing , performance: 1.0917051132909132
# Heuristic : best_fit_decreasing , performance: 1.0942795115263386
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0592322078418586
# Heuristic : next_fit_decreasing , performance: 1.034632146261451
# Heuristic : best_fit_decreasing , performance: 1.1279659253778116
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1462312757856945
# Heuristic : next_fit_decreasing , performance: 1.0456196953134664
# Heuristic : best_fit_decreasing , performance: 1.1368103698501033
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0169371059849899
# Heuristic : next_fit_decreasing , performance: 1.007748267246459
# Heuristic : best_fit_decreasing , performance: 1.0269951198836622
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0711034760959028
# Heuristic : next_fit_decreasing , performance: 1.0278337498430836
# Heuristic : best_fit_decreasing , performance: 1.0641815717365144
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1258225157108925
# Heuristic : next_fit_decreasing , performance: 1.0924869955236711
# Heuristic : best_fit_decreasing , performance: 1.166583510773382
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.030331712399284
# Heuristic : next_fit_decreasing , performance: 1.1717612382325528
# Heuristic : best_fit_decreasing , performance: 1.141718790306673
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0698994881158486
# Heuristic : next_fit_decreasing , performance: 1.165747085330751
# Heuristic : best_fit_decreasing , performance: 1.0298653109749627
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.014505572867651
# Heuristic : next_fit_decreasing , performance: 1.0088201364897307
# Heuristic : best_fit_decreasing , performance: 1.1456930373110152
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0967069784033878
# Heuristic : next_fit_decreasing , performance: 1.1343245929151649
# Heuristic : best_fit_decreasing , performance: 1.0172418405458712
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0027779433354593
# Heuristic : next_fit_decreasing , performance: 1.0879227242413954
# Heuristic : best_fit_decreasing , performance: 1.0987181158645944
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0000749295882374
# Heuristic : next_fit_decreasing , performance: 1.1566491322563244
# Heuristic : best_fit_decreasing , performance: 1.1035964901295652
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1386340456683044
# Heuristic : next_fit_decreasing , performance: 1.0207010992463994
# Heuristic : best_fit_decreasing , performance: 1.0909554250764677
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1365716691158103
# Heuristic : next_fit_decreasing , performance: 1.13785974473046
# Heuristic : best_fit_decreasing , performance: 1.0970834745160982
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.032627021661022
# Heuristic : next_fit_decreasing , performance: 1.1764045966368253
# Heuristic : best_fit_decreasing , performance: 1.0298066017117358
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0465506606129669
# Heuristic : next_fit_decreasing , performance: 1.0938852652773927
# Heuristic : best_fit_decreasing , performance: 1.010205572042093
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0634625307808296
# Heuristic : next_fit_decreasing , performance: 1.104258520851145
# Heuristic : best_fit_decreasing , performance: 1.0586368752620678
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0742072152266509
# Heuristic : next_fit_decreasing , performance: 1.1271318623023687
# Heuristic : best_fit_decreasing , performance: 1.1072489005802812
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1196410232674738
# Heuristic : next_fit_decreasing , performance: 1.1536669986217052
# Heuristic : best_fit_decreasing , performance: 1.0510251643593158
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1877803137989258
# Heuristic : next_fit_decreasing , performance: 1.157508639436052
# Heuristic : best_fit_decreasing , performance: 1.1862962655889366
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1608406473601085
# Heuristic : next_fit_decreasing , performance: 1.0618423615726031
# Heuristic : best_fit_decreasing , performance: 1.0296295456374267
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0214807692655028
# Heuristic : next_fit_decreasing , performance: 1.0965329461197066
# Heuristic : best_fit_decreasing , performance: 1.180475567161266
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1182403140821189
# Heuristic : next_fit_decreasing , performance: 1.1879399429560151
# Heuristic : best_fit_decreasing , performance: 1.0405477813454194
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0411061692643462
# Heuristic : next_fit_decreasing , performance: 1.1389412295992813
# Heuristic : best_fit_decreasing , performance: 1.182614382332898
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1607757956430091
# Heuristic : next_fit_decreasing , performance: 1.0992864374712983
# Heuristic : best_fit_decreasing , performance: 1.104388447886083
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1083540566288521
# Heuristic : next_fit_decreasing , performance: 1.0071061134799593
# Heuristic : best_fit_decreasing , performance: 1.0462147055578503
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0149094771864682
# Heuristic : next_fit_decreasing , performance: 1.1587872446319833
# Heuristic : best_fit_decreasing , performance: 1.1786512078748081
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0327817234746153
# Heuristic : next_fit_decreasing , performance: 1.0582894488147176
# Heuristic : best_fit_decreasing , performance: 1.0385344756775023
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0012131416335253
# Heuristic : next_fit_decreasing , performance: 1.1361120587923783
# Heuristic : best_fit_decreasing , performance: 1.1070408205722906
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0408135341036724
# Heuristic : next_fit_decreasing , performance: 1.122690323889876
# Heuristic : best_fit_decreasing , performance: 1.1703362462528641
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0835328552149976
# Heuristic : next_fit_decreasing , performance: 1.1905732106014437
# Heuristic : best_fit_decreasing , performance: 1.1642497341426865
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1472378202227485
# Heuristic : next_fit_decreasing , performance: 1.1248893729493161
# Heuristic : best_fit_decreasing , performance: 1.12654814573208
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0809047968465637
# Heuristic : next_fit_decreasing , performance: 1.1810262445475181
# Heuristic : best_fit_decreasing , performance: 1.1411205023725677
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0266933631778816
# Heuristic : next_fit_decreasing , performance: 1.0901538136374735
# Heuristic : best_fit_decreasing , performance: 1.1562239670478447
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0660922562350807
# Heuristic : next_fit_decreasing , performance: 1.0925548180879219
# Heuristic : best_fit_decreasing , performance: 1.023962326476505
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0068859865223199
# Heuristic : next_fit_decreasing , performance: 1.051997521557538
# Heuristic : best_fit_decreasing , performance: 1.0345486698727502
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0819087445990356
# Heuristic : next_fit_decreasing , performance: 1.0590109195570163
# Heuristic : best_fit_decreasing , performance: 1.127330344959564
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0200140231174804
# Heuristic : next_fit_decreasing , performance: 1.1394148521139253
# Heuristic : best_fit_decreasing , performance: 1.027647186085556
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.132194399876286
# Heuristic : next_fit_decreasing , performance: 1.1515980639303403
# Heuristic : best_fit_decreasing , performance: 1.0615401181886888
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0461967350640133
# Heuristic : next_fit_decreasing , performance: 1.0503831764620752
# Heuristic : best_fit_decreasing , performance: 1.0025265025106695
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0569849518882166
# Heuristic : next_fit_decreasing , performance: 1.027576307029144
# Heuristic : best_fit_decreasing , performance: 1.0754390210501952
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0678508212471494
# Heuristic : next_fit_decreasing , performance: 1.1788496008067435
# Heuristic : best_fit_decreasing , performance: 1.0885311771605082
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0262522232854492
# Heuristic : next_fit_decreasing , performance: 1.045253432196169
# Heuristic : best_fit_decreasing , performance: 1.003303130643735
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1839433296479451
# Heuristic : next_fit_decreasing , performance: 1.0662458789842646
# Heuristic : best_fit_decreasing , performance: 1.1007368051000035
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1915549380112846
# Heuristic : next_fit_decreasing , performance: 1.1165321771826158
# Heuristic : best_fit_decreasing , performance: 1.0678593680251816
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0429650199884977
# Heuristic : next_fit_decreasing , performance: 1.0951513771868069
# Heuristic : best_fit_decreasing , performance: 1.0981231123022928
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1111412041947493
# Heuristic : next_fit_decreasing , performance: 1.0403086335224345
# Heuristic : best_fit_decreasing , performance: 1.1159487172421396
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0639445503129437
# Heuristic : next_fit_decreasing , performance: 1.0210477896380246
# Heuristic : best_fit_decreasing , performance: 1.085018833257038
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0785979477013459
# Heuristic : next_fit_decreasing , performance: 1.112112785561177
# Heuristic : best_fit_decreasing , performance: 1.117928739151072
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.127375325257847
# Heuristic : next_fit_decreasing , performance: 1.1345875293497023
# Heuristic : best_fit_decreasing , performance: 1.1793792602970903
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0410439695670586
# Heuristic : next_fit_decreasing , performance: 1.112839391552326
# Heuristic : best_fit_decreasing , performance: 1.0293388799891856
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1160271216797966
# Heuristic : next_fit_decreasing , performance: 1.0395796274256457
# Heuristic : best_fit_decreasing , performance: 1.1557198087889815
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0472566005206063
# Heuristic : next_fit_decreasing , performance: 1.1949592819783423
# Heuristic : best_fit_decreasing , performance: 1.1535221366580994
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1430176373666008
# Heuristic : next_fit_decreasing , performance: 1.1494388614892108
# Heuristic : best_fit_decreasing , performance: 1.038508401558484
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1247011743635436
# Heuristic : next_fit_decreasing , performance: 1.0774668989422367
# Heuristic : best_fit_decreasing , performance: 1.0650635276044997
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1666449076157859
# Heuristic : next_fit_decreasing , performance: 1.1112975062347021
# Heuristic : best_fit_decreasing , performance: 1.0724696873722632
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1240845532763928
# Heuristic : next_fit_decreasing , performance: 1.0609428110164458
# Heuristic : best_fit_decreasing , performance: 1.0079942507156021
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1377982137785707
# Heuristic : next_fit_decreasing , performance: 1.0790236373655995
# Heuristic : best_fit_decreasing , performance: 1.0522691449826376
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1609702063704042
# Heuristic : next_fit_decreasing , performance: 1.044136168611061
# Heuristic : best_fit_decreasing , performance: 1.1874746044702398
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0098533668080714
# Heuristic : next_fit_decreasing , performance: 1.0106154645798433
# Heuristic : best_fit_decreasing , performance: 1.0914194450576904
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0551459975034836
# Heuristic : next_fit_decreasing , performance: 1.0403822441998072
# Heuristic : best_fit_decreasing , performance: 1.0568709694778844
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1891553535158423
# Heuristic : next_fit_decreasing , performance: 1.1479851017130938
# Heuristic : best_fit_decreasing , performance: 1.04382771561979
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0116050311323979
# Heuristic : next_fit_decreasing , performance: 1.1804262193188482
# Heuristic : best_fit_decreasing , performance: 1.1852686430725954
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0000019094211088
# Heuristic : next_fit_decreasing , performance: 1.102300626547054
# Heuristic : best_fit_decreasing , performance: 1.1226484530713197
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1739531707194666
# Heuristic : next_fit_decreasing , performance: 1.208511210414433
# Heuristic : best_fit_decreasing , performance: 1.0113861485775135
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.146847931664352
# Heuristic : next_fit_decreasing , performance: 1.0366379113257167
# Heuristic : best_fit_decreasing , performance: 1.0818029460698309
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1045828777608317
# Heuristic : next_fit_decreasing , performance: 1.0761963267610863
# Heuristic : best_fit_decreasing , performance: 1.1885440864666288
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.044519509055035
# Heuristic : next_fit_decreasing , performance: 1.1992629891427558
# Heuristic : best_fit_decreasing , performance: 1.1540313868122256
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1283380816011963
# Heuristic : next_fit_decreasing , performance: 1.1547443719010129
# Heuristic : best_fit_decreasing , performance: 1.1235566368726415
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1778859351360698
# Heuristic : next_fit_decreasing , performance: 1.0078068541657002
# Heuristic : best_fit_decreasing , performance: 1.0975881751397047
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.193325629303748
# Heuristic : next_fit_decreasing , performance: 1.0994887043612653
# Heuristic : best_fit_decreasing , performance: 1.0164428371870702
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1935237039092124
# Heuristic : next_fit_decreasing , performance: 1.1882363240337963
# Heuristic : best_fit_decreasing , performance: 1.2043178641736665
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.062976891532202
# Heuristic : next_fit_decreasing , performance: 1.009204888193942
# Heuristic : best_fit_decreasing , performance: 1.0382954985096207
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.204218510283415
# Heuristic : next_fit_decreasing , performance: 1.0460926162928041
# Heuristic : best_fit_decreasing , performance: 1.1179838479399826
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0261565183282932
# Heuristic : next_fit_decreasing , performance: 1.146488419643373
# Heuristic : best_fit_decreasing , performance: 1.169454885650853
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1520197316635707
# Heuristic : next_fit_decreasing , performance: 1.1743132622618282
# Heuristic : best_fit_decreasing , performance: 1.004897752934502
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.02624836317159
# Heuristic : next_fit_decreasing , performance: 1.1995527348469506
# Heuristic : best_fit_decreasing , performance: 1.1428119573103266
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1734907848417975
# Heuristic : next_fit_decreasing , performance: 1.0463231744456747
# Heuristic : best_fit_decreasing , performance: 1.0746878136520464
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0202657555527717
# Heuristic : next_fit_decreasing , performance: 1.0902156063295303
# Heuristic : best_fit_decreasing , performance: 1.08377080987009
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.037335259684072
# Heuristic : next_fit_decreasing , performance: 1.0511696523193246
# Heuristic : best_fit_decreasing , performance: 1.1049641614164463
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.185281282050535
# Heuristic : next_fit_decreasing , performance: 1.0582078744474404
# Heuristic : best_fit_decreasing , performance: 1.1619401375539056
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1303916876879847
# Heuristic : next_fit_decreasing , performance: 1.1326414224056773
# Heuristic : best_fit_decreasing , performance: 1.0977093796130755
# selected heuristic : next_fit_decreasing
#
# ...
# Heuristic : best_fit_decreasing , performance: 1.1844754958052455
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0826990691836142
# Heuristic : next_fit_decreasing , performance: 1.0511042054323365
# Heuristic : best_fit_decreasing , performance: 1.0434317876803778
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.031958480091645
# Heuristic : next_fit_decreasing , performance: 1.0374463213399976
# Heuristic : best_fit_decreasing , performance: 1.1717917511888962
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0580895026024844
# Heuristic : next_fit_decreasing , performance: 1.161242941671289
# Heuristic : best_fit_decreasing , performance: 1.050955655312389
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0583286629160609
# Heuristic : next_fit_decreasing , performance: 1.0260841890118046
# Heuristic : best_fit_decreasing , performance: 1.0495010227513413
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1923260509051241
# Heuristic : next_fit_decreasing , performance: 1.050758506936491
# Heuristic : best_fit_decreasing , performance: 1.0990008882795315
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.191902167533707
# Heuristic : next_fit_decreasing , performance: 1.0683166374550286
# Heuristic : best_fit_decreasing , performance: 1.0781893784658751
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1481898478123302
# Heuristic : next_fit_decreasing , performance: 1.0822124609751298
# Heuristic : best_fit_decreasing , performance: 1.0968315945357001
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0514449829939074
# Heuristic : next_fit_decreasing , performance: 1.0538048641010742
# Heuristic : best_fit_decreasing , performance: 1.0101401062483975
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1208373068946043
# Heuristic : next_fit_decreasing , performance: 1.0743529013684694
# Heuristic : best_fit_decreasing , performance: 1.1235821436829805
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1075165871130566
# Heuristic : next_fit_decreasing , performance: 1.0247801133021206
# Heuristic : best_fit_decreasing , performance: 1.0396564105558777
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.024293505456675
# Heuristic : next_fit_decreasing , performance: 1.1350736045270295
# Heuristic : best_fit_decreasing , performance: 1.1006602852483358
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1712171536264724
# Heuristic : next_fit_decreasing , performance: 1.0102606840310415
# Heuristic : best_fit_decreasing , performance: 1.1484202653291673
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1577201230330938
# Heuristic : next_fit_decreasing , performance: 1.0866870101100705
# Heuristic : best_fit_decreasing , performance: 1.1836675890624682
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0669294179562516
# Heuristic : next_fit_decreasing , performance: 1.0790419034157064
# Heuristic : best_fit_decreasing , performance: 1.1962392228822485
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0057572631093903
# Heuristic : next_fit_decreasing , performance: 1.1655014093443268
# Heuristic : best_fit_decreasing , performance: 1.0502587457196693
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0123523619552564
# Heuristic : next_fit_decreasing , performance: 1.1931792886044088
# Heuristic : best_fit_decreasing , performance: 1.1620986258266743
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1077695487973005
# Heuristic : next_fit_decreasing , performance: 1.1504368942706409
# Heuristic : best_fit_decreasing , performance: 1.033685490253149
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0911281541009985
# Heuristic : next_fit_decreasing , performance: 1.1709048903162413
# Heuristic : best_fit_decreasing , performance: 1.0591987525195559
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1872965220711307
# Heuristic : next_fit_decreasing , performance: 1.0776661965742107
# Heuristic : best_fit_decreasing , performance: 1.1661639859394992
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1938607055758972
# Heuristic : next_fit_decreasing , performance: 1.0027447804170115
# Heuristic : best_fit_decreasing , performance: 1.004507644274105
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0623692312101338
# Heuristic : next_fit_decreasing , performance: 1.1455047891764556
# Heuristic : best_fit_decreasing , performance: 1.1000509580350157
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1312177834074155
# Heuristic : next_fit_decreasing , performance: 1.1849009786940201
# Heuristic : best_fit_decreasing , performance: 1.1408570223027936
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1285354727502546
# Heuristic : next_fit_decreasing , performance: 1.1435764500116221
# Heuristic : best_fit_decreasing , performance: 1.1518164503012724
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.015808355494208
# Heuristic : next_fit_decreasing , performance: 1.1935638161008888
# Heuristic : best_fit_decreasing , performance: 1.1193168677750942
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1395997983859958
# Heuristic : next_fit_decreasing , performance: 1.1916839354866462
# Heuristic : best_fit_decreasing , performance: 1.1766679378945004
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0147413459667065
# Heuristic : next_fit_decreasing , performance: 1.0117519096213683
# Heuristic : best_fit_decreasing , performance: 1.1748377223264543
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0415322015167394
# Heuristic : next_fit_decreasing , performance: 1.055811151246163
# Heuristic : best_fit_decreasing , performance: 1.0245109619670352
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0116004694753071
# Heuristic : next_fit_decreasing , performance: 1.0780995097048562
# Heuristic : best_fit_decreasing , performance: 1.0934099236522066
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0106024693983735
# Heuristic : next_fit_decreasing , performance: 1.1379372677271218
# Heuristic : best_fit_decreasing , performance: 1.1848255829592371
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1167358152725249
# Heuristic : next_fit_decreasing , performance: 1.0685853858154593
# Heuristic : best_fit_decreasing , performance: 1.1549235168465732
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.153172513401851
# Heuristic : next_fit_decreasing , performance: 1.1847268124384358
# Heuristic : best_fit_decreasing , performance: 1.081727806976456
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0260580564456772
# Heuristic : next_fit_decreasing , performance: 1.1334349030265392
# Heuristic : best_fit_decreasing , performance: 1.178323729671058
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1600417103194502
# Heuristic : next_fit_decreasing , performance: 1.1343884120205565
# Heuristic : best_fit_decreasing , performance: 1.0768935336855396
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0360953369425419
# Heuristic : next_fit_decreasing , performance: 1.2023011111716289
# Heuristic : best_fit_decreasing , performance: 1.0366693044560997
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1692628592043608
# Heuristic : next_fit_decreasing , performance: 1.069858353818792
# Heuristic : best_fit_decreasing , performance: 1.1715969672151303
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0415483198136137
# Heuristic : next_fit_decreasing , performance: 1.042572552916069
# Heuristic : best_fit_decreasing , performance: 1.1539636248085958
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0005679166958619
# Heuristic : next_fit_decreasing , performance: 1.1162574883892706
# Heuristic : best_fit_decreasing , performance: 1.0399774436925773
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1571962740247959
# Heuristic : next_fit_decreasing , performance: 1.12903778444253
# Heuristic : best_fit_decreasing , performance: 1.1990756165370018
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0674378593230673
# Heuristic : next_fit_decreasing , performance: 1.0248201038046563
# Heuristic : best_fit_decreasing , performance: 1.155236507808208
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0466999910294281
# Heuristic : next_fit_decreasing , performance: 1.037513074404115
# Heuristic : best_fit_decreasing , performance: 1.0098001091321227
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1129024826420748
# Heuristic : next_fit_decreasing , performance: 1.1125999232323311
# Heuristic : best_fit_decreasing , performance: 1.0532067542798296
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1485119713789904
# Heuristic : next_fit_decreasing , performance: 1.2025836156255614
# Heuristic : best_fit_decreasing , performance: 1.0195982038493636
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0244436808621429
# Heuristic : next_fit_decreasing , performance: 1.1136492596540422
# Heuristic : best_fit_decreasing , performance: 1.1242823704600988
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0399468326464487
# Heuristic : next_fit_decreasing , performance: 1.0114371768565047
# Heuristic : best_fit_decreasing , performance: 1.0989352953957388
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0124408048641265
# Heuristic : next_fit_decreasing , performance: 1.1532361199103547
# Heuristic : best_fit_decreasing , performance: 1.2058162500468372
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0970510547239551
# Heuristic : next_fit_decreasing , performance: 1.0581663640801875
# Heuristic : best_fit_decreasing , performance: 1.0617110628835422
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1841876424621933
# Heuristic : next_fit_decreasing , performance: 1.2015324780663015
# Heuristic : best_fit_decreasing , performance: 1.162671264129542
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0172063187569753
# Heuristic : next_fit_decreasing , performance: 1.20130403135808
# Heuristic : best_fit_decreasing , performance: 1.1784825245355997
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0345358081778508
# Heuristic : next_fit_decreasing , performance: 1.2007056991593141
# Heuristic : best_fit_decreasing , performance: 1.095959661328358
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0159838878168668
# Heuristic : next_fit_decreasing , performance: 1.0967152138150489
# Heuristic : best_fit_decreasing , performance: 1.2067118998354354
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0855924228048779
# Heuristic : next_fit_decreasing , performance: 1.0094474137899272
# Heuristic : best_fit_decreasing , performance: 1.1314251881980162
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.2082461401194668
# Heuristic : next_fit_decreasing , performance: 1.0486022557133456
# Heuristic : best_fit_decreasing , performance: 1.0340675144449314
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.030848495698867
# Heuristic : next_fit_decreasing , performance: 1.1376324191510896
# Heuristic : best_fit_decreasing , performance: 1.1787691388442512
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.079446041354874
# Heuristic : next_fit_decreasing , performance: 1.1238643766912242
# Heuristic : best_fit_decreasing , performance: 1.1514782797554526
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.006941007805724
# Heuristic : next_fit_decreasing , performance: 1.0273795006514432
# Heuristic : best_fit_decreasing , performance: 1.016846855605061
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0807141855179563
# Heuristic : next_fit_decreasing , performance: 1.0270913993591155
# Heuristic : best_fit_decreasing , performance: 1.158795539453199
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0222166623814921
# Heuristic : next_fit_decreasing , performance: 1.0720056797840973
# Heuristic : best_fit_decreasing , performance: 1.018141050960382
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0401840738478487
# Heuristic : next_fit_decreasing , performance: 1.1911346602315718
# Heuristic : best_fit_decreasing , performance: 1.0950259075165722
# selected heuristic : next_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.2038773814504085
# Heuristic : next_fit_decreasing , performance: 1.0507314648524226
# Heuristic : best_fit_decreasing , performance: 1.0826489550793894
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.174642077226085
# Heuristic : next_fit_decreasing , performance: 1.024623995128852
# Heuristic : best_fit_decreasing , performance: 1.0391870446488978
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.0011758071954693
# Heuristic : next_fit_decreasing , performance: 1.0496189823906332
# Heuristic : best_fit_decreasing , performance: 1.0821604231420754
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1789706349047342
# Heuristic : next_fit_decreasing , performance: 1.0919633980786065
# Heuristic : best_fit_decreasing , performance: 1.1903355039927188
# selected heuristic : best_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.2080878356917994
# Heuristic : next_fit_decreasing , performance: 1.1248203594613064
# Heuristic : best_fit_decreasing , performance: 1.1044639611457763
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.1640404560409396
# Heuristic : next_fit_decreasing , performance: 1.1312768846965127
# Heuristic : best_fit_decreasing , performance: 1.1231928311960584
# selected heuristic : first_fit_decreasing
#
# Heuristic : first_fit_decreasing , performance: 1.195265713729962
# Heuristic : next_fit_decreasing , performance: 1.084163009739671
# Heuristic : best_fit_decreasing , performance: 1.0107843516834212
#
# Round 8: Selected Heuristic - first_fit_decreasing, Number of Bins Used - 67
# [70, 26]
# [70, 26]
# [70, 26]
# [70, 26]
# [67, 29]
# [67, 29]
# [67, 29]
# [65, 29]
# [65, 29]
# [65, 29]
# [65, 29]
# [65, 29]
# [65, 29]
# [65, 29]
# [65, 29]
# [62, 29]
# [62, 29]
